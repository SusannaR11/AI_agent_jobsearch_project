# %%
import duckdb
import pandas as pd
from pathlib import Path

df = pd.read_json("data/yrkesbarometer (1).json")

df.shape
# Out:
# (4818, 19)

# %%
df.columns
# Out:
# Index(['yrkesomrade', 'yb_yrke', 'yb_concept_id', 'lan', 'antal_ssyk',
#        'del_av_ssyk', 'ssyk', 'ssyk_text', 'yb_beskrivning', 'jobbmojligheter',
#        'rekryteringssituation', 'paradox', 'prognos', 'text_jobbmojligheter',
#        'text_rekryteringssituation', 'hogsta_bedomningsniva', 'delvis_helt',
#        'omgang', 'taxonomi_version'],
#       dtype='str')

# %%
df.head()
# Out:
#                         yrkesomrade                     yb_yrke yb_concept_id  \
# 0  Administration, ekonomi, juridik  Administrativa assistenter  PDNm_NZ2_WRh
# 1  Administration, ekonomi, juridik  Administrativa assistenter  PDNm_NZ2_WRh
# 2  Administration, ekonomi, juridik  Administrativa assistenter  PDNm_NZ2_WRh
# 3  Administration, ekonomi, juridik  Administrativa assistenter  PDNm_NZ2_WRh
# 4  Administration, ekonomi, juridik  Administrativa assistenter  PDNm_NZ2_WRh
#
#    lan  antal_ssyk  del_av_ssyk  ssyk  \
# 0    0           1            0  4119
# 1    1           1            0  4119
# 2    3           1            0  4119
# 3    4           1            0  4119
# 4    5           1            0  4119
#
#                                    ssyk_text yb_beskrivning jobbmojligheter  \
# 0  Övriga kontorsassistenter och sekreterare            NaN             små
# 1  Övriga kontorsassistenter och sekreterare            NaN             små
# 2  Övriga kontorsassistenter och sekreterare            NaN      medelstora
# 3  Övriga kontorsassistenter och sekreterare            NaN             små
# 4  Övriga kontorsassistenter och sekreterare            NaN             små
#
#   rekryteringssituation paradox          prognos  \
# 0             överskott      []  vara oförändrad
# 1             överskott      []  vara oförändrad
# 2                balans      []  vara oförändrad
# 3             överskott      []  vara oförändrad
# 4             överskott      []  vara oförändrad
#
#                                 text_jobbmojligheter  \
# 0  Nationellt bedöms möjligheterna till arbete so...
# 1  Möjligheterna till arbete som administrativ as...
# 2  Möjligheterna till arbete som administrativ as...
# 3  Möjligheterna till arbete som administrativ as...
# 4  Möjligheterna till arbete som administrativ as...
#
#                           text_rekryteringssituation hogsta_bedomningsniva  \
# 0  Nationellt bedöms rekryteringssituationen för ...            nationellt
# 1  Rekryteringssituationen för administrativa ass...                   län
# 2  Rekryteringssituationen för administrativa ass...                 nuts2
# 3  Rekryteringssituationen för administrativa ass...                   län
# 4  Rekryteringssituationen för administrativa ass...                 nuts2
#
#   delvis_helt  omgang  taxonomi_version
# 0        helt  2025-2                27
# 1        helt  2025-2                27
# 2      delvis  2025-2                27
# 3        helt  2025-2                27
# 4      delvis  2025-2                27

# %%
df["text_rekryteringssituation"].value_counts().head(60)
# Out:
# text_rekryteringssituation
# På grund av begränsat underlag görs ingen bedömning för yrket.                                                                                                                                                                                                                                                                          1336
# Nationellt bedöms rekryteringssituationen för administrativa assistenter kännetecknas av överskott. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                                   1
# Rekryteringssituationen för administrativa assistenter i Stockholms län bedöms kännetecknas av överskott. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                             1
# Rekryteringssituationen för administrativa assistenter i Uppsala län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                       1
# Rekryteringssituationen för administrativa assistenter i Södermanlands län bedöms kännetecknas av överskott. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                          1
# Rekryteringssituationen för administrativa assistenter i Östergötlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                              1
# Rekryteringssituationen för administrativa assistenter i Jönköpings län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                 1
# Rekryteringssituationen för administrativa assistenter i Kronobergs län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                 1
# Rekryteringssituationen för administrativa assistenter i Kalmar län bedöms kännetecknas av överskott. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                                 1
# Rekryteringssituationen för administrativa assistenter i Gotlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                   1
# Rekryteringssituationen för administrativa assistenter i Blekinge län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                   1
# Rekryteringssituationen för administrativa assistenter i Skåne län bedöms kännetecknas av överskott. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                                  1
# Rekryteringssituationen för administrativa assistenter i Hallands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                      1
# Rekryteringssituationen för administrativa assistenter i Västra Götalands län bedöms kännetecknas av balans. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                          1
# Rekryteringssituationen för administrativa assistenter i Värmlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                  1
# Rekryteringssituationen för administrativa assistenter i Örebro län bedöms kännetecknas av balans. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                                    1
# Rekryteringssituationen för administrativa assistenter i Västmanlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                               1
# Rekryteringssituationen för administrativa assistenter i Dalarnas län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                      1
# Rekryteringssituationen för administrativa assistenter i Gävleborgs län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                 1
# Rekryteringssituationen för administrativa assistenter i Västernorrlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                            1
# Rekryteringssituationen för administrativa assistenter i Jämtlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                     1
# Rekryteringssituationen för administrativa assistenter i Västerbottens län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                 1
# Rekryteringssituationen för administrativa assistenter i Norrbottens län bedöms kännetecknas av balans. På fem års sikt förväntas efterfrågan på administrativa assistenter vara oförändrad.                                                                                                                                               1
# Nationellt bedöms rekryteringssituationen för arbetsförmedlare kännetecknas av balans. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                                                                                                                                     1
# Rekryteringssituationen för arbetsförmedlare i Stockholms län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                        1
# Rekryteringssituationen för arbetsförmedlare i Uppsala län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                        1
# Rekryteringssituationen för arbetsförmedlare i Södermanlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                  1
# Rekryteringssituationen för arbetsförmedlare i Östergötlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                             1
# Rekryteringssituationen för arbetsförmedlare i Jönköpings län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                     1
# Rekryteringssituationen för arbetsförmedlare i Kronobergs län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                1
# Rekryteringssituationen för arbetsförmedlare i Kalmar län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                         1
# Rekryteringssituationen för arbetsförmedlare i Gotlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                       1
# Rekryteringssituationen för arbetsförmedlare i Blekinge län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                     1
# Rekryteringssituationen för arbetsförmedlare i Skåne län bedöms kännetecknas av överskott. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                                                                                                                                      1
# Rekryteringssituationen för arbetsförmedlare i Hallands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                  1
# Rekryteringssituationen för arbetsförmedlare i Västra Götalands län bedöms kännetecknas av balans. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                                                                                                                         1
# Rekryteringssituationen för arbetsförmedlare i Värmlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                 1
# Rekryteringssituationen för arbetsförmedlare i Örebro län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                       1
# Rekryteringssituationen för arbetsförmedlare i Västmanlands län bedöms kännetecknas av överskott. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                              1
# Rekryteringssituationen för arbetsförmedlare i Dalarnas län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare vara oförändrad.                                                          1
# Rekryteringssituationen för arbetsförmedlare i Gävleborgs län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                   1
# Rekryteringssituationen för arbetsförmedlare i Västernorrlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                              1
# Rekryteringssituationen för arbetsförmedlare i Jämtlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                    1
# Rekryteringssituationen för arbetsförmedlare i Västerbottens län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                1
# Rekryteringssituationen för arbetsförmedlare i Norrbottens län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på arbetsförmedlare öka jämfört med idag.                                                  1
# Nationellt bedöms rekryteringssituationen för chefssekreterare och VD-assistenter kännetecknas av balans. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.                                                                                                                               1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Stockholms län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.             1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Uppsala län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter vara oförändrad.                     1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Södermanlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.          1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Östergötlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.          1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Jönköpings län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.             1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Kronobergs län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.             1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Kalmar län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.                 1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Gotlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.               1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Blekinge län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.               1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Skåne län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.                  1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Hallands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.               1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Västra Götalands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.       1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Värmlands län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.              1
# Rekryteringssituationen för chefssekreterare och VD-assistenter i Örebro län bedöms kännetecknas av balans. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan på chefssekreterare och VD-assistenter öka jämfört med idag.                 1
# Name: count, dtype: int64

# %%
df["text_jobbmojligheter"].value_counts().head(100)
# Out:
# text_jobbmojligheter
# På grund av begränsat underlag görs ingen bedömning för yrket.                                                                                                                                                                                                    1336
# Nationellt bedöms möjligheterna till arbete som administrativ assistent vara små. På fem års sikt förväntas efterfrågan vara oförändrad.                                                                                                                             1
# Möjligheterna till arbete som administrativ assistent bedöms vara små i Stockholms län. På fem års sikt förväntas efterfrågan vara oförändrad.                                                                                                                       1
# Möjligheterna till arbete som administrativ assistent bedöms vara medelstora i Uppsala län. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan vara oförändrad.       1
# Möjligheterna till arbete som administrativ assistent bedöms vara små i Södermanlands län. På fem års sikt förväntas efterfrågan vara oförändrad.                                                                                                                    1
#                                                                                                                                                                                                                                                                   ...
# Möjligheterna till arbete som ekonomiassistent bedöms vara medelstora i Kronobergs län. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan vara oförändrad.           1
# Möjligheterna till arbete som ekonomiassistent bedöms vara små i Kalmar län. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan vara oförändrad.                      1
# Möjligheterna till arbete som ekonomiassistent bedöms vara små i Gotlands län. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan vara oförändrad.                    1
# Möjligheterna till arbete som ekonomiassistent bedöms vara små i Blekinge län. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan vara oförändrad.                    1
# Möjligheterna till arbete som ekonomiassistent bedöms vara små i Skåne län. På grund av begränsat underlag baseras bedömningen delvis på information för ett större geografiskt område. På fem års sikt förväntas efterfrågan vara oförändrad.                       1
# Name: count, Length: 100, dtype: int64

# %%
df["lan"].value_counts()
# Out:
# lan
# 0     219
# 1     219
# 3     219
# 4     219
# 5     219
# 6     219
# 7     219
# 8     219
# 9     219
# 10    219
# 12    219
# 13    219
# 14    219
# 17    219
# 18    219
# 19    219
# 20    219
# 21    219
# 22    219
# 23    219
# 24    219
# 25    219
# Name: count, dtype: int64

# %%
df["yrkesomrade"].value_counts()
# Out:
# yrkesomrade
# Hälso- och sjukvård                   638
# Administration, ekonomi, juridik      418
# Bygg och anläggning                   374
# Industriell tillverkning              374
# Transport                             352
# Försäljning, inköp, marknadsföring    308
# Tekniskt arbete                       308
# Hotell, restaurang, storhushåll       242
# Installation, drift, underhåll        242
# Pedagogiskt arbete                    242
# Socialt arbete                        242
# Data/IT                               220
# Naturbruk                             220
# Kultur, media, design                 198
# Naturvetenskapligt arbete             110
# Säkerhetsarbete                       110
# Sanering och renhållning               88
# Hantverksyrken                         66
# Kropps- och skönhetsvård               66
# Name: count, dtype: int64

# %%
df["yb_yrke"].nunique()
# Out:
# 219

# %%
df["yb_yrke"].unique()
# Out:
# <ArrowStringArray>
# [             'Administrativa assistenter',
#                         'Arbetsförmedlare',
#      'Chefssekreterare och VD-assistenter',
#                              'Controllrar',
#                       'Ekonomiassistenter',
#       'Finansanalytiker och finansmäklare',
#          'Informatörer och kommunikatörer',
#                                 'Jurister',
#                    'Kontorsreceptionister',
#    'Lednings- och organisationsutvecklare',
#  ...
#                           'Kranbilsförare',
#              'Lager- och terminalpersonal',
#                           'Lastbilsförare',
#                                'Lokförare',
#                              'Maskinbefäl',
#                     'Matroser och jungmän',
#                  'Ramp- och flyttpersonal',
#                               'Taxiförare',
#  'Transportledare och transportsamordnare',
#                              'Truckförare']
# Length: 219, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4818 entries, 0 to 4817
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   yrkesomrade                 4818 non-null   str
#  1   yb_yrke                     4818 non-null   str
#  2   yb_concept_id               4818 non-null   str
#  3   lan                         4818 non-null   int64
#  4   antal_ssyk                  4818 non-null   int64
#  5   del_av_ssyk                 4818 non-null   int64
#  6   ssyk                        4818 non-null   str
#  7   ssyk_text                   4818 non-null   str
#  8   yb_beskrivning              814 non-null    str
#  9   jobbmojligheter             3482 non-null   str
#  10  rekryteringssituation       3482 non-null   str
#  11  paradox                     4818 non-null   object
#  12  prognos                     3482 non-null   str
#  13  text_jobbmojligheter        4818 non-null   str
#  14  text_rekryteringssituation  4818 non-null   str
#  15  hogsta_bedomningsniva       3594 non-null   str
#  16  delvis_helt                 3594 non-null   str
#  17  omgang                      4818 non-null   str
#  18  taxonomi_version            4818 non-null   int64
# dtypes: int64(4), object(1), str(14)
# memory usage: 3.6+ MB

# %%
df["omgang"].unique() #När senase data togs fram från AF
# Out:
# <ArrowStringArray>
# ['2025-2']
# Length: 1, dtype: str

# %%
df["paradox"]       # Den här fattar jag inte riktigt?
# Out:
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 4813    []
# 4814    []
# 4815    []
# 4816    []
# 4817    []
# Name: paradox, Length: 4818, dtype: object

# %%
df["delvis_helt"].unique()
# Out:
# <ArrowStringArray>
# ['helt', 'delvis', nan]
# Length: 3, dtype: str

# %%
df["jobbmojligheter"].unique()
# Out:
# <ArrowStringArray>
# ['små', 'medelstora', nan, 'stora']
# Length: 4, dtype: str

# %%
df["taxonomi_version"]
# Out:
# 0       27
# 1       27
# 2       27
# 3       27
# 4       27
#         ..
# 4813    27
# 4814    27
# 4815    27
# 4816    27
# 4817    27
# Name: taxonomi_version, Length: 4818, dtype: int64

# %%
df_with_prognosis = df[df["prognos"].notna()]

df_with_prognosis.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3482 entries, 0 to 4817
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   yrkesomrade                 3482 non-null   str
#  1   yb_yrke                     3482 non-null   str
#  2   yb_concept_id               3482 non-null   str
#  3   lan                         3482 non-null   int64
#  4   antal_ssyk                  3482 non-null   int64
#  5   del_av_ssyk                 3482 non-null   int64
#  6   ssyk                        3482 non-null   str
#  7   ssyk_text                   3482 non-null   str
#  8   yb_beskrivning              615 non-null    str
#  9   jobbmojligheter             3482 non-null   str
#  10  rekryteringssituation       3482 non-null   str
#  11  paradox                     3482 non-null   object
#  12  prognos                     3482 non-null   str
#  13  text_jobbmojligheter        3482 non-null   str
#  14  text_rekryteringssituation  3482 non-null   str
#  15  hogsta_bedomningsniva       3482 non-null   str
#  16  delvis_helt                 3482 non-null   str
#  17  omgang                      3482 non-null   str
#  18  taxonomi_version            3482 non-null   int64
# dtypes: int64(4), object(1), str(14)
# memory usage: 3.1+ MB

# %%
df_with_prognosis["ssyk_text"].unique()
# Out:
# <ArrowStringArray>
# [                                                                          'Övriga kontorsassistenter och sekreterare',
#                                                                                                     'Arbetsförmedlare',
#                                                                            'Chefssekreterare och VD-assistenter m.fl.',
#                                                                                                           'Controller',
#                                                                                             'Ekonomiassistenter m.fl.',
#                                                                     'Informatörer, kommunikatörer och PR-specialister',
#  'Advokater, Domare, Åklagare, Affärs- och företagsjurister, Förvaltnings- och organisationsjurister, Övriga jurister',
#                                                                                                'Kontorsreceptionister',
#                                                                                'Lednings- och organisationsutvecklare',
#                                                                                    'Löne- och personaladministratörer',
#  ...
#                                                                            'Ingenjörer och tekniker inom maskinteknik',
#                                                                                                'Laboratorieingenjörer',
#                                                                                                           'Lantmätare',
#                                                                                           'Planeringsarkitekter m.fl.',
#                                                                                            'Buss- och spårvagnsförare',
#                                                                                                 'Lastbilsförare m.fl.',
#                                                                                          'Lager- och terminalpersonal',
#                                                                                                     'Taxiförare m.fl.',
#                                                                              'Transportledare och transportsamordnare',
#                                                                                                          'Truckförare']
# Length: 148, dtype: str

# %%
df_with_prognosis.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3482 entries, 0 to 4817
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   yrkesomrade                 3482 non-null   str
#  1   yb_yrke                     3482 non-null   str
#  2   yb_concept_id               3482 non-null   str
#  3   lan                         3482 non-null   int64
#  4   antal_ssyk                  3482 non-null   int64
#  5   del_av_ssyk                 3482 non-null   int64
#  6   ssyk                        3482 non-null   str
#  7   ssyk_text                   3482 non-null   str
#  8   yb_beskrivning              615 non-null    str
#  9   jobbmojligheter             3482 non-null   str
#  10  rekryteringssituation       3482 non-null   str
#  11  paradox                     3482 non-null   object
#  12  prognos                     3482 non-null   str
#  13  text_jobbmojligheter        3482 non-null   str
#  14  text_rekryteringssituation  3482 non-null   str
#  15  hogsta_bedomningsniva       3482 non-null   str
#  16  delvis_helt                 3482 non-null   str
#  17  omgang                      3482 non-null   str
#  18  taxonomi_version            3482 non-null   int64
# dtypes: int64(4), object(1), str(14)
# memory usage: 3.1+ MB

# %%
df["lan"].unique()
# Out:
# array([ 0,  1,  3,  4,  5,  6,  7,  8,  9, 10, 12, 13, 14, 17, 18, 19, 20,
#        21, 22, 23, 24, 25])

# %%
df["taxonomi_version"].unique()
# Out:
# array([27])

# %%
df["yrkesomrade"].unique()
# Out:
# <ArrowStringArray>
# [  'Administration, ekonomi, juridik',                'Bygg och anläggning',
#                             'Data/IT', 'Försäljning, inköp, marknadsföring',
#                      'Hantverksyrken',    'Hotell, restaurang, storhushåll',
#                 'Hälso- och sjukvård',           'Industriell tillverkning',
#      'Installation, drift, underhåll',           'Kropps- och skönhetsvård',
#               'Kultur, media, design',                          'Naturbruk',
#           'Naturvetenskapligt arbete',                 'Pedagogiskt arbete',
#            'Sanering och renhållning',                     'Socialt arbete',
#                     'Säkerhetsarbete',                    'Tekniskt arbete',
#                           'Transport']
# Length: 19, dtype: str

# %%
df_it = df[df["yrkesomrade"].str.contains("Data/IT", na=False)]
print("Rows:", len(df_it))
print("Unique yb_yrke:", df_it["yb_yrke"].nunique())
print("Unique yb_concept_id:", df_it["yb_concept_id"].nunique())
# Out:
# Rows: 220
# Unique yb_yrke: 10
# Unique yb_concept_id: 10

# %%
df_admin = df[df["yrkesomrade"].str.contains("Administration, ekonomi, juridik", na = False)]

print("Rows:", len(df_admin))
print("Unique yb_yrke:", df_admin["yb_yrke"].nunique())
print("Unique yb_concept_id:", df_admin["yb_concept_id"].nunique())
# Out:
# Rows: 418
# Unique yb_yrke: 19
# Unique yb_concept_id: 19

# %%
df_hs = df[df["yrkesomrade"].str.contains("Hälso- och sjukvård", na = False)]

print("Rows:", len(df_hs))
print("Unique yb_yrke:", df_hs["yb_yrke"].nunique())
print("Unique yb_concept_id:", df_hs["yb_concept_id"].nunique())
# Out:
# Rows: 638
# Unique yb_yrke: 29
# Unique yb_concept_id: 29
